# %% [markdown]
# # Mock Exam 1
#
# **KF Python Course**
#
# *March 09, 2025*
# ___

# %% [markdown]
# ## Exam Structure:
#
# For every section:
#
# - Conceptual Question (No Computer)
# - Code Analysis Question (No Computer)
# - Programming Question  (Computer Allowed)
#
#
# ## Section 1: Variables, Built-in Functions & Operators
#
# 1. What is the difference between `=` and `==` in Python?
# 2. What will be the output of the following code?
# <div style="background-color: rgba(52, 58, 64, 0.25);">
#
# ```py
#     x = 10
#     y = 3
#     print(x // y, x % y, x ** y)
# ```
#
# </div>
#
# 3. What will be the output of the following code?
#
# <div style="background-color: rgba(52, 58, 64, 0.25);">
#
# ```py
#     a = 5
#     b = 2
#     a += b * 3
#     print(a)
# ```
#
# </div>
#
# 4. Write code to convert the string `"42"` to an integer and then add 8 to it.
#
# ## Section 2: Strings
#
# 5. Why does the following code cause an error?
#
# <div style="background-color: rgba(52, 58, 64, 0.25);">
#
# ```py
#     s = "hello"
#     s[0] = "H"
# ```
# </div>
#
# 6. What will be the output of the following code?
#
# <div style="background-color: rgba(52, 58, 64, 0.25);">
#
# ```py
#     greeting = "Hello, World!"
#     print(greeting[::-1])
# ```
# </div>
#
# 7. Create a string that contains the following text on multiple lines without using several print statements:
# <div style="background-color: rgba(52, 58, 64, 0.25);">
#
# ```raw
#     Line 1: Hello
#     Line 2: World
#     Line 3: Python
# ```
#
# </div>
#
#
# ## Section 3: Lists & Tuples
#
# 8. What is the difference between a list and a tuple in Python?
# 9. What will be the output of the following code?
#
# <div style="background-color: rgba(52, 58, 64, 0.25);">
#
# ```py
#     numbers = [1, 2, 3, 4, 5]
#     numbers[1:4] = [10, 20]
#     print(numbers)
# ```
#
# </div>
# 10. Write code to create a list of the first 10 square numbers (1, 4, 9, 16, ...).
#
# ## Section 4: Dictionaries & Sets
#
# 11. Explain the difference between `update()` and `union()` in sets
# 12. Given the dictionary: `student = {"name": "Alice", "age": 20, "grade": "A"}`
#
#     How do you:
#     - Access the value of `"age"`?
#     - Add a new key-value pair `"course": "Math"`?
# 13. Write code to create a set of unique letters from the string `"mississippi"`
#
# ## Section 5: Conditionals
#
# 14. Explain the difference between `if`, `elif`, and `else` statements in Python
#
# 15. What will be the output of:
#
# <div style="background-color: rgba(52, 58, 64, 0.25);">
#
# ```py
#     x = 5
#     if x:
#         print("Hello")
# ```
#
# </div>
#
# 16. Write a function that returns the absolute value of a number without using the built-in `abs()` function
#
# ## Section 6: Loops
#
# 17. What is the difference between `continue` and `break` in loops?
#
# 18. What will be the output of the following code?
#
# <div style="background-color: rgba(52, 58, 64, 0.25);">
#
# ```py
#     for i in range(3):
#         for j in range(2):
#             print(f"({i},{j})")
# ```
#
# </div>
#
# 19. Write code using a while loop to find the sum of all numbers from 1 to 100.
#
# ## Section 7: Functions
#
# 20. What is the difference between parameters and arguments in Python functions?
#
# 21. What will be the output of the following code?
#
# <div style="background-color: rgba(52, 58, 64, 0.25);">
#
# ```py
#     def greet(name, greeting="Hello"):
#         return f"{greeting}, {name}!"
#
#     print(greet("Alice"))
#     print(greet("Bob", "Hi"))
# ```
#
# </div>
#
# 22. Write a function that takes a variable number of arguments and returns their sum
